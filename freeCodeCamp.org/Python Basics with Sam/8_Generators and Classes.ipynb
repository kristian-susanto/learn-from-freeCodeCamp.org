# %%
# class rect():
#   def __init__(self, length, width):
#     self.length = length
#     self.width = width
#     # print(f'Your rectangle is {length} by {width}')

#   def __repr__(self):
#     return "rect({self.length},{self.width})".format(self=self)

#   def __str__(self):
#     return f'Your rectangle is {self.width} by {self.length}'

#   def perim(self):
#     print(2*self.width*self.length)

#   def area(self):
#     print(self.width*self.length)

# x = rect(3, 4)

# # Menampilkan hasil
# print(x)         # str(x) dipanggil secara implisit
# print(str(x))    # str(x) dipanggil secara eksplisit
# print(repr(x))   # repr(x) dipanggil secara eksplisit
# Out:
# Your rectangle is 4 by 3
# Your rectangle is 4 by 3
# rect(3,4)

# %%
# class Dog():
#   species = 'Canine'
#   voice = 'Bark'

# class poodle(Dog):
#   pass

# rusty = poodle()
# print(rusty.voice)
# print(rusty.species)
# Out:
# Bark
# Canine

# %%
# name = 'Sam'

# name = iter(name)

# # for i in name:
# #   print(i)

# print(name)
# print(next(name))
# print(next(name))
# print(next(name))
# Out:
# <str_ascii_iterator object at 0x7989d1242020>
# S
# a
# m

# %%
# # generative
# def series(num):
#   n = 0
#   while n < num:
#     yield n
#     n += 1

# five = series(5)
# print(five)
# print(next(five))
# print(next(five))
# print(next(five))
# print(next(five))
# print(next(five))
# Out:
# <generator object series at 0x7989d0356cf0>
# 0
# 1
# 2
# 3
# 4

# %%
# '''
# 78 --> 80
# 77 --> 77
# 93 --> 95
# 72 --> 72
# 74 --> 75
# '''

# def fives(x):
#   if x%5 == 4:
#     x += 1
#   elif x%5 == 3:
#     x += 2
#   print(x)

# grades = [72,98,94,83,71,73,100]

# for grade in grades:
#   print(grade, end=' '), fives(grade)
# Out:
# 72 72
# 98 100
# 94 95
# 83 85
# 71 71
# 73 75
# 100 100

# %%
def fives(x):
  if x%5 == 3 or x%5 == 4:
    x += (5 - x%5)
  print(x)

grades = [72,98,94,83,71,73,100]

for grade in grades:
  print(grade, end=' '), fives(grade)
# Out:
# 72 72
# 98 100
# 94 95
# 83 85
# 71 71
# 73 75
# 100 100
