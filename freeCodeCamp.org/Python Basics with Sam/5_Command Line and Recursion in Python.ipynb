# %%
# def fact(x):
#   tot = 1
#   while x > 0:
#     tot *= x
#     x -= 1
#   print(tot)

# tests = [3,4,1,8,12,18,100]

# for test in tests:
#   fact(test)
# Out:
# 6
# 24
# 1
# 40320
# 479001600
# 6402373705728000
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
# tests = [3,4,1,0,-2,8,12,18,100]

# def fact(n):
#   if n > -1:
#     if n == 0:
#       return 1
#     else:
#       return n * fact(n-1)
#   else:
#     return "Negative"

# for test in tests:
#   print(fact(test))
# Out:
# 6
# 24
# 1
# 1
# Negative
# 40320
# 479001600
# 6402373705728000
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
# # lottery powerball

# def odds(balls,pick,power=False):
#   """Enter number a regular balls, number of balls
#     picked, and if they are using a powerball, you will be asked
#     for the number of powerballs"""
#   from math import factorial as fact
#   p_ball = 1
#   if power:
#     p_ball = int(input("Enter number of powerballs: "))
#   return (fact(balls))/(fact(5)*fact(balls-pick))*p_ball

# # print("{:,}".format(odds(69,6)))
# print(f"{odds(69,6):,}")
# Out:
# 719,264,832.0

# %%
# import sys

# # print(sys.argv)

# if len(sys.argv) > 1:
#   print(f"Hello {sys.argv[1]}")
#   print(sys.argv)
# else:
#   print(f"Hello world!")
# Out:
# Hello -f
# ['/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-c1c10b92-ae39-4329-938f-d285bbde37ed.json']

# %%
# import sys

# if len(sys.argv) == 2:
#   print(f"Hello sys.argv[1]")
#   print(sys.argv)
# elif len(sys.argv) == 3:
#   print(f"Hello sys.argv[1], I hear you are {sys.argv[2]}")
#   print(sys.argv)
# else:
#   print(f"Hello world!")
#   print(sys.argv)
# Out:
# Hello sys.argv[1], I hear you are /root/.local/share/jupyter/runtime/kernel-c1c10b92-ae39-4329-938f-d285bbde37ed.json
# ['/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-c1c10b92-ae39-4329-938f-d285bbde37ed.json']

# %%
# dictionary

d = {}

d['Sam'] = 43

fruit = {'banana': 3, 'apples': 1, 'grapes': 2}

for k,v in fruit.items():
  print(f'I have {v} {k}')
# Out:
# I have 3 banana
# I have 1 apples
# I have 2 grapes
