# %%
# x = ['sam', 41, 'bob', 36, 'steve', '20']

# name = [True for i in x if str(i).isnumeric()]

# # name = [False if str(i).isnumeric() else True for i in x]

# name
# Out:
# [True, True, True]

# %%
from string import ascii_lowercase as letters
from random import choice

a_f = list(letters[:6].upper())

num = iter(range(1,7))

hidden = [choice(a_f) + str(choice(list(range(1,7)))) for i in range(4)]

arr = [[ "O" for i in range(6)] for i in range(6)]

play = True

while play:
  num = iter(range(1,7))
  print(hidden)
  print(f'Find the {len(hidden)} hidden X\'s')
  print('  '+' '.join(a_f))
  for i in arr:
    print(next(num), end = ' ')
    print(' '.join(i))
  move = input("""
    Q to Quit
    Enter move (eg. A5):
  """)
  if move.lower() == 'q':
    play = False
  else:
    if move in hidden:
      hidden.pop(hidden.index(move))
      move = list(move)
      arr[int(move[1]) - 1][a_f.index(move[0])] = "X"
    else:
      move = list(move)
      arr[int(move[1]) - 1][a_f.index(move[0])] = " "
# Out:
# ['B5', 'C6', 'F3', 'B2']
# Find the 4 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O O O O O O
# 3 O O O O O O
# 4 O O O O O O
# 5 O O O O O O
# 6 O O O O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   B6
# ['B5', 'C6', 'F3', 'B2']
# Find the 4 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O O O O O O
# 3 O O O O O O
# 4 O O O O O O
# 5 O O O O O O
# 6 O   O O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   B4
# ['B5', 'C6', 'F3', 'B2']
# Find the 4 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O O O O O O
# 3 O O O O O O
# 4 O   O O O O
# 5 O O O O O O
# 6 O   O O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   B5
# ['C6', 'F3', 'B2']
# Find the 3 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O O O O O O
# 3 O O O O O O
# 4 O   O O O O
# 5 O X O O O O
# 6 O   O O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   F3
# ['C6', 'B2']
# Find the 2 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O O O O O O
# 3 O O O O O X
# 4 O   O O O O
# 5 O X O O O O
# 6 O   O O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   B2
# ['C6']
# Find the 1 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O X O O O O
# 3 O O O O O X
# 4 O   O O O O
# 5 O X O O O O
# 6 O   O O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   C6
# []
# Find the 0 hidden X's
#   A B C D E F
# 1 O O O O O O
# 2 O X O O O O
# 3 O O O O O X
# 4 O   O O O O
# 5 O X O O O O
# 6 O   X O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   A1
# []
# Find the 0 hidden X's
#   A B C D E F
# 1   O O O O O
# 2 O X O O O O
# 3 O O O O O X
# 4 O   O O O O
# 5 O X O O O O
# 6 O   X O O O
#
#     Q to Quit
#     Enter move (eg. A5):
#   Q
