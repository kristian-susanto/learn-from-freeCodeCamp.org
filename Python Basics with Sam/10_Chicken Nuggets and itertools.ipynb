# %%
# t,n,s = 20,9,6

# def nuggets(tt1):
#   global x
#   x = {}
#   for i in range(10):
#     for j in range(10):
#       for k in range(10):
#         tot = i*t+j*n+k*s
#         x[tot] = [i,j,k]
#         if tt1 == tot:
#           break
#       if tt1 == tot:
#         break
#     if tt1 == tot:
#       break
#   print(f"""{tt1}
#     {x[tt1][2]}: 6 piece
#     {x[tt1][1]}: 9 piece
#     {x[tt1][0]}: 20 piece
#   """)

# comb = []

# for i in range(101):
#   try:
#     nuggets(i)
#     comb.append(i)
#   except:
#     print(i, 'no results')
# Out:
# 0
#     0: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 1 no results
# 2 no results
# 3 no results
# 4 no results
# 5 no results
# 6
#     1: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 7 no results
# 8 no results
# 9
#     0: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 10 no results
# 11 no results
# 12
#     2: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 13 no results
# 14 no results
# 15
#     1: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 16 no results
# 17 no results
# 18
#     3: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 19 no results
# 20
#     0: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 21
#     2: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 22 no results
# 23 no results
# 24
#     4: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 25 no results
# 26
#     1: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 27
#     3: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 28 no results
# 29
#     0: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 30
#     5: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 31 no results
# 32
#     2: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 33
#     4: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 34 no results
# 35
#     1: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 36
#     6: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 37 no results
# 38
#     3: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 39
#     5: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 40
#     0: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 41
#     2: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 42
#     7: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 43 no results
# 44
#     4: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 45
#     6: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 46
#     1: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 47
#     3: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 48
#     8: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 49
#     0: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 50
#     5: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 51
#     7: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 52
#     2: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 53
#     4: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 54
#     9: 6 piece
#     0: 9 piece
#     0: 20 piece
#
# 55
#     1: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 56
#     6: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 57
#     8: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 58
#     3: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 59
#     5: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 60
#     7: 6 piece
#     2: 9 piece
#     0: 20 piece
#
# 61
#     2: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 62
#     7: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 63
#     9: 6 piece
#     1: 9 piece
#     0: 20 piece
#
# 64
#     4: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 65
#     6: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 66
#     8: 6 piece
#     2: 9 piece
#     0: 20 piece
#
# 67
#     3: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 68
#     8: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 69
#     7: 6 piece
#     3: 9 piece
#     0: 20 piece
#
# 70
#     5: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 71
#     7: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 72
#     9: 6 piece
#     2: 9 piece
#     0: 20 piece
#
# 73
#     4: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 74
#     9: 6 piece
#     0: 9 piece
#     1: 20 piece
#
# 75
#     8: 6 piece
#     3: 9 piece
#     0: 20 piece
#
# 76
#     6: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 77
#     8: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 78
#     7: 6 piece
#     4: 9 piece
#     0: 20 piece
#
# 79
#     5: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 80
#     7: 6 piece
#     2: 9 piece
#     1: 20 piece
#
# 81
#     9: 6 piece
#     3: 9 piece
#     0: 20 piece
#
# 82
#     7: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 83
#     9: 6 piece
#     1: 9 piece
#     1: 20 piece
#
# 84
#     8: 6 piece
#     4: 9 piece
#     0: 20 piece
#
# 85
#     6: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 86
#     8: 6 piece
#     2: 9 piece
#     1: 20 piece
#
# 87
#     7: 6 piece
#     5: 9 piece
#     0: 20 piece
#
# 88
#     8: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 89
#     7: 6 piece
#     3: 9 piece
#     1: 20 piece
#
# 90
#     9: 6 piece
#     4: 9 piece
#     0: 20 piece
#
# 91
#     7: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 92
#     9: 6 piece
#     2: 9 piece
#     1: 20 piece
#
# 93
#     8: 6 piece
#     5: 9 piece
#     0: 20 piece
#
# 94
#     9: 6 piece
#     0: 9 piece
#     2: 20 piece
#
# 95
#     8: 6 piece
#     3: 9 piece
#     1: 20 piece
#
# 96
#     7: 6 piece
#     6: 9 piece
#     0: 20 piece
#
# 97
#     8: 6 piece
#     1: 9 piece
#     2: 20 piece
#
# 98
#     7: 6 piece
#     4: 9 piece
#     1: 20 piece
#
# 99
#     9: 6 piece
#     5: 9 piece
#     0: 20 piece
#
# 100
#     7: 6 piece
#     2: 9 piece
#     2: 20 piece

# %%
# from itertools import chain

# x = 'abc'
# y = 'def'
# z = 'ghi'

# # for i in chain(x,y,z):
# #   print(i)

# arr = {x,y,z}

# for i in chain.from_iterable(arr):
#   print(i)
# Out:
# a
# b
# c
# g
# h
# i
# d
# e
# f

# %%
# from itertools import combinations as comb
# letter = "ABCDEFG"

# x = comb(letter,3)

# y = [''.join(i) for i in x]

# print(x)
# print(y)
# Out:
# <itertools.combinations object at 0x794bdc56b7e0>
# ['ABC', 'ABD', 'ABE', 'ABF', 'ABG', 'ACD', 'ACE', 'ACF', 'ACG', 'ADE', 'ADF', 'ADG', 'AEF', 'AEG', 'AFG', 'BCD', 'BCE', 'BCF', 'BCG', 'BDE', 'BDF', 'BDG', 'BEF', 'BEG', 'BFG', 'CDE', 'CDF', 'CDG', 'CEF', 'CEG', 'CFG', 'DEF', 'DEG', 'DFG', 'EFG']

# %%
# from itertools import count

# x = count(1)

# print(x)
# print(x)
# print(x)
# print(next(x))
# print(x)
# print(x)
# print(x)
# print(next(x))
# print(x)
# Out:
# count(1)
# count(1)
# count(1)
# 1
# count(2)
# count(2)
# count(2)
# 2
# count(3)

# %%
'''
    1
  2 3 4
5 6 7 8 9
'''

from itertools import count

start = count(1,2) # it's the starting point

num = count(1)

for i in range(1,4):
  print(('  ')*(3-i), end = '')
  for j in range(next(start)):
    print(next(num), end = ' ')
  print()
# Out:
#     1
#   2 3 4
# 5 6 7 8 9
