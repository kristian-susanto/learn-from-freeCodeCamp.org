# %%
my_favorite_color = 'blue'
my_favorite_color
# Out:
# 'blue'

# %%
color1, color2, color3 = 'red', 'green', 'blue'

# %%
color1
# Out:
# 'red'

# %%
color2
# Out:
# 'green'

# %%
color3
# Out:
# 'blue'

# %%
color4 = color5 = color6 = 'magenta'

# %%
color4
# Out:
# 'magenta'

# %%
color5
# Out:
# 'magenta'

# %%
color6
# Out:
# 'magenta'

# %%
my_favorite_color = 'red'

# %%
my_favorite_color
# Out:
# 'red'

# %%
counter = 10

# %%
counter = counter + 1

# %%
counter
# Out:
# 11

# %%
counter = 10

# %%
# Same as `counter = counter + 4`
counter += 4

# %%
counter
# Out:
# 14

# %%
a_variable = 23
is_today_Saturday = False
my_favorite_car = 'Delorean'
the_3_musketeers = ['Athos', 'Porthos', 'Aramis']

# %%
a_variable
# Out:
# 23

# %%
type(a_variable)
# Out:
# int

# %%
is_today_Saturday
# Out:
# False

# %%
type(is_today_Saturday)
# Out:
# bool

# %%
my_favorite_car
# Out:
# 'Delorean'

# %%
type(my_favorite_car)
# Out:
# str

# %%
the_3_musketeers
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %%
type(the_3_musketeers)
# Out:
# list

# %%
current_year = 2020

# %%
current_year
# Out:
# 2020

# %%
type(current_year)
# Out:
# int

# %%
a_large_negative_number = -23374038374832934334234317348343

# %%
a_large_negative_number
# Out:
# -23374038374832934334234317348343

# %%
type(a_large_negative_number)
# Out:
# int

# %%
pi = 3.1415

# %%
pi
# Out:
# 3.1415

# %%
type(pi)
# Out:
# float

# %%
a_number = 3.0

# %%
a_number
# Out:
# 3.0

# %%
type(a_number)
# Out:
# float

# %%
another_number = 4.

# %%
another_number
# Out:
# 4.0

# %%
type(another_number)
# Out:
# float

# %%
one_hundredth = 1e-2

# %%
one_hundredth
# Out:
# 0.01

# %%
type(one_hundredth)
# Out:
# float

# %%
avogadro_number = 6.02214076e23

# %%
avogadro_number
# Out:
# 6.02214076e+23

# %%
type(avogadro_number)
# Out:
# float

# %%
float(current_year)
# Out:
# 2020.0

# %%
float(a_large_negative_number)
# Out:
# -2.3374038374832935e+31

# %%
int(pi)
# Out:
# 3

# %%
int(avogadro_number)
# Out:
# 602214075999999987023872

# %%
type(45 * 3.0)
# Out:
# float

# %%
type(45 * 3)
# Out:
# int

# %%
type(10/3)
# Out:
# float

# %%
type(10/2)
# Out:
# float

# %%
type(10//2)
# Out:
# int

# %%
is_today_Sunday = True

# %%
is_today_Sunday
# Out:
# True

# %%
type(is_today_Sunday)
# Out:
# bool

# %%
cost_of_ice_bag = 1.25
is_ice_bag_expensive = cost_of_ice_bag >= 10

# %%
is_ice_bag_expensive
# Out:
# False

# %%
type(is_ice_bag_expensive)
# Out:
# bool

# %%
5 + False
# Out:
# 5

# %%
3. + True
# Out:
# 4.0

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(set())
# Out:
# False

# %%
bool(range(0))
# Out:
# False

# %%
bool(True), bool(1), bool(2.0), bool('hello'), bool([1,2]), bool((2,3)), bool(range(10))
# Out:
# (True, True, True, True, True, True, True)

# %%
nothing = None

# %%
type(nothing)
# Out:
# NoneType

# %%
today = 'Saturday'

# %%
today
# Out:
# 'Saturday'

# %%
type(today)
# Out:
# str

# %%
my_favorite_movie = 'One Flew over the Cuckoo\'s Neat'

# %%
my_favorite_movie
# Out:
# "One Flew over the Cuckoo's Neat"

# %%
my_favorite_pun = 'Thanks for explaining the word \'many\' to me, it means a lot'

# %%
my_favorite_pun
# Out:
# "Thanks for explaining the word 'many' to me, it means a lot"

# %%
yet_another_pun = '''Son: "Dad, you can tell me what a solar eclipse is?"
Dad: "No sun."'''

# %%
yet_another_pun
# Out:
# 'Son: "Dad, you can tell me what a solar eclipse is?"\nDad: "No sun."'

# %%
print(yet_another_pun)
# Out:
# Son: "Dad, you can tell me what a solar eclipse is?"
# Dad: "No sun."

# %%
a_music_pun = '''
Two windmills are standing in a field and one asks the other,
"What kind of music do you like?"

The other says,
"I'm a big metal fan"
'''

# %%
print(a_music_pun)
# Out:
# Two windmills are standing in a field and one asks the other,
# "What kind of music do you like?"
#
# The other says,
# "I'm a big metal fan"

# %%
len(my_favorite_movie)
# Out:
# 31

# %%
multiline_string = """a
b"""
multiline_string
# Out:
# 'a\nb'

# %%
len(multiline_string)
# Out:
# 3

# %%
list(multiline_string)
# Out:
# ['a', '\n', 'b']

# %%
today = 'Saturday'

# %%
today[0]
# Out:
# 'S'

# %%
today[3]
# Out:
# 'u'

# %%
today[7]
# Out:
# 'y'

# %%
today[5:8]
# Out:
# 'day'

# %%
'day' in today
# Out:
# True

# %%
'Sun' in today
# Out:
# False

# %%
full_name = 'Derek O\'Brien'

# %%
greeting = 'Hello'

# %%
greeting + full_name
# Out:
# "HelloDerek O'Brien"

# %%
greeting + " " + full_Name + '!' # additional space
# Out:
# "Hello Derek O'Brien!"

# %%
today.lower()
# Out:
# 'saturday'

# %%
'saturday'.upper()
# Out:
# 'SATURDAY'

# %%
'monday'.capitalize() # changes first character to uppercase
# Out:
# 'Monday'

# %%
another_day = today.replace('Satur', 'Wednes')

# %%
another_day
# Out:
# 'Wednesday'

# %%
today
# Out:
# 'Saturday'

# %%
'Sun,Mon,Tue,Wed,Thu,Fri,Sat'.split(',')
# Out:
# ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

# %%
a_long_line = '     This is a long line with some space.'

# %%
a_long_line_stripped = a_long_line.strip()

# %%
a_long_line_stripped
# Out:
# 'This is a long line with some space.'

# %%
# Input variables
cost_of_ice_bag = 1.25
profit_margin = .2
number_of_bags = 500

# Template for output message
output_template = """If a grocery store sells ice bags as % {} per bag, with a profit margin of {} %, then the total profit it makes by selling {} ice bags is $ {}."""

print(output_template)
# Out:
# If a grocery store sells ice bags as % {} per bag, with a profit margin of {} %, then the total profit it makes by selling {} ice bags is $ {}.

# %%
# Inserting values into the string
total_profit = cost_of_ice_bag * profit_margin * number_of_bags
output_message = output_template.format(cost_of_ice_bag, profit_margin, number_of_bags, total_profit)

print(output_message)
# Out:
# If a grocery store sells ice bags as % 1.25 per bag, with a profit margin of 0.2 %, then the total profit it makes by selling 500 ice bags is $ 125.0.

# %%
"If a grocery store sells ice bags at $ " + str(cost_of_ice_bag) + ", with a profit margin of " + str(profit_margin)
# Out:
# 'If a grocery store sells ice bags at $ 1.25, with a profit margin of 0.2'

# %%
str(23)
# Out:
# '23'

# %%
str(23.432)
# Out:
# '23.432'

# %%
str(True)
# Out:
# 'True'

# %%
the_3_musketeers = ['Athos', 'Porthos', 'Aramis']
str(the_3_musketeers)
# Out:
# "['Athos', 'Porthos', 'Aramis']"

# %%
first_name = 'John'

# %%
first_name == 'Doe'
# Out:
# False

# %%
first_name == 'John'
# Out:
# True

# %%
first_name != 'Jane'
# Out:
# True

# %%
fruits = ['apple','banana','cherry']

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
type(fruits)
# Out:
# list

# %%
a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
empty_list = []

# %%
empty_list
# Out:
# []

# %%
len(fruits)
# Out:
# 3

# %%
print('Number of fruits:', len(fruits))
# Out:
# Number of fruits: 3

# %%
len(a_list)
# Out:
# 6

# %%
len(empty_list)
# Out:
# 0

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[1]
# Out:
# 'banana'

# %%
fruits[2]
# Out:
# 'cherry'

# %%
fruits[-1]
# Out:
# 'cherry'

# %%
fruits[-2]
# Out:
# 'banana'

# %%
fruits[-3]
# Out:
# 'apple'

# %%
a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
len(a_list)
# Out:
# 6

# %%
a_list[2:5]
# Out:
# [None, 3.14, ['apple', 'banana', 'cherry']]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[1] = 'bluberry'

# %%
fruits
# Out:
# ['apple', 'bluberry', 'cherry']

# %%
fruits.append('dates')

# %%
fruits
# Out:
# ['apple', 'bluberry', 'cherry', 'dates']

# %%
fruits.insert(1, 'banana')

# %%
fruits
# Out:
# ['apple', 'banana', 'bluberry', 'cherry', 'dates']

# %%
fruits.remove('bluberry')

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'dates']

# %%
fruits.pop(1)
# Out:
# 'banana'

# %%
fruits
# Out:
# ['apple', 'cherry', 'dates']

# %%
fruits.pop()
# Out:
# 'dates'

# %%
fruits
# Out:
# ['apple', 'cherry']

# %%
'pineapple' in fruits
# Out:
# False

# %%
'cherry' in fruits
# Out:
# True

# %%
fruits
# Out:
# ['apple', 'cherry']

# %%
more_fruits = fruits + ['pineapple', 'tomato', 'guava'] + ['dates', 'banana']

# %%
more_fruits
# Out:
# ['apple', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
more_fruits_copy = more_fruits.copy()

# %%
more_fruits_copy
# Out:
# ['apple', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
# Modify the copy
more_fruits_copy.remove('pineapple')
more_fruits_copy.pop()
more_fruits_copy
# Out:
# ['apple', 'cherry', 'tomato', 'guava', 'dates']

# %%
# Original list remains unchanged
more_fruits
# Out:
# ['apple', 'cherry', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
more_fruits_not_a_copy = more_fruits

# %%
more_fruits_not_a_copy.remove('pineapple')
more_fruits_not_a_copy.pop()
# Out:
# 'banana'

# %%
more_fruits_not_a_copy
# Out:
# ['apple', 'cherry', 'tomato', 'guava', 'dates']

# %%
more_fruits
# Out:
# ['apple', 'cherry', 'tomato', 'guava', 'dates']

# %%
fruits = ('apple','cherry','dates')

# %%
# check no. of elements
len(fruits)
# Out:
# 3

# %%
# get an element (positive index)
fruits[0]
# Out:
# 'apple'

# %%
# get an element (negative index)
fruits[-2]
# Out:
# 'cherry'

# %%
# check if it contains an element
'dates' in fruits
# Out:
# True

# %%
the_3_musketeers = ['Athos', 'Porthos', 'Aramis']

# %%
the_3_musketeers
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %%
single_element_tuple = 4,

# %%
single_element_tuple
# Out:
# (4,)

# %%
another_single_element_tuple = (4,)

# %%
another_single_element_tuple
# Out:
# (4,)

# %%
not_a_tuple = (4)

# %%
not_a_tuple
# Out:
# 4

# %%
point = (3, 4)

# %%
point_x, point_y = point

# %%
point_x
# Out:
# 3

# %%
point_y
# Out:
# 4

# %%
tuple(['one','two','three'])
# Out:
# ('one', 'two', 'three')

# %%
list(('Athos','Porthos','Aramis'))
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %%
a_tuple = 23, 'hello', False, None, 23, 37, 'hello'

# %%
help(a_tuple.count)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.tuple instance
#     Return number of occurrences of value.

# %%
# ?a_tuple.index

# %%
person1 = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person2 = dict(name='Jane Judy', sex='Female', age=28, married=False)

# %%
person2
# Out:
# {'name': 'Jane Judy', 'sex': 'Female', 'age': 28, 'married': False}

# %%
type(person1)
# Out:
# dict

# %%
type(person2)
# Out:
# dict

# %%
person1['name']
# Out:
# 'John Doe'

# %%
person1['married']
# Out:
# True

# %%
person2['name']
# Out:
# 'Jane Judy'

# %%
person2.get('name')
# Out:
# 'Jane Judy'

# %%
person2.get('address','Unknown')
# Out:
# 'Unknown'

# %%
'name' in person1
# Out:
# True

# %%
'address' in person1
# Out:
# False

# %%
person2['married']
# Out:
# False

# %%
person2['married'] = True

# %%
person2['married']
# Out:
# True

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1['address'] = '1, Penny Lane'

# %%
person1
# Out:
# {'name': 'John Doe',
#  'sex': 'Male',
#  'age': 32,
#  'married': True,
#  'address': '1, Penny Lane'}

# %%
person1.pop('address')
# Out:
# '1, Penny Lane'

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])

# %%
person1.values()
# Out:
# dict_values(['John Doe', 'Male', 32, True])

# %%
person1.items()
# Out:
# dict_items([('name', 'John Doe'), ('sex', 'Male'), ('age', 32), ('married', True)])

# %% [markdown]
# https://www.w3schools.com/python/python_ref_dictionary.asp
